# %% [markdown]
# Web scraping trying

# %%
import requests 
import numpy as np
import pandas as pd
import time
import random
import os

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

service = Service(ChromeDriverManager().install()) #Automatically finds the ChromeDriver and makes sure its updated
driver = webdriver.Chrome(service=service)

# %%
driver.get('https://batdongsan.com.vn/nha-dat-ban')

# %%
xpath = '//*[@id="product-lists-web"]/div[1]/a/div[2]/div[1]/div[1]/div[1]/span[1]' # remember you can just copy the xpath

title_element=driver.find_element('xpath', xpath)

print(title_element.text)
# Out:
# 4,3 tỷ
