# %% [markdown]
# Packages and stuff

# %%
import numpy as np
import pandas as pd
import openpyxl
import os
import matplotlib.pyplot as plt

# %% [markdown]
# Some data
# - Housing prices by district
# - Spatial cost of living index among provinces
# - Monthly consumer price index

# %%
#Ho chi minh city housing price data broken down by district
hp = pd.read_csv("HousePricingHCM.csv") # from kaggle, thinking could be target
sD = pd.read_excel("hochiSpatialcost.xlsx") # from vitnam national statistis office
cPI = pd.read_csv("consumerPriceIndex.csv")  # from vitnam national statistis office
spatialData = sD.T.set_index(1).drop(columns=0)
cPIData = cPI.T.dropna(axis=1)

# %% [markdown]
# Data from the world bank below

# %%
population = pd.read_excel("populationData.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 population = pd.read_excel("populationData.xlsx")
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Below is graphing the housing prices

# %%
hp.plot(figsize = (16,8))
ax.set(title="House Pricing in Ho Chi Minh 2017-2022", 
       ylabel="Million/m2")
plt.show()
